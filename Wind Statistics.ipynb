# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate as interp
from trajectory import Wind

# %%
wind=[Wind(-4.005,52.4245,run_date="20201217"),Wind(-4.005,52.4245,run_date="20201218"),Wind(-4.005,52.4245,run_date="20201219")]

# %%
w=[[],[],[]]
for n in range(0,3):
    for a in range(0,25000):
        point=wind[n].get_wind(-4.005,52.4245,a)
        w[n].append(point)

# %%
# Out:
# [<matplotlib.lines.Line2D at 0x1a1dfe4290>,
#  <matplotlib.lines.Line2D at 0x1a1df072d0>,
#  <matplotlib.lines.Line2D at 0x1a1dfe43d0>]

# %%
wind_0=[Wind(-4.005,52.4245,run_date="20201208"),Wind(-4.005,52.4245,run_date="20201209"),Wind(-4.005,52.4245,run_date="20201210")]
# Out:
# Downloading files
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-ffee850e7932> in <module>
# ----> 1 wind_0=[Wind(-4.005,52.4245,run_date="20201208"),Wind(-4.005,52.4245,run_date="20201209"),Wind(-4.005,52.4245,run_date="20201210")]
#
# ~/Documents/Projects/6DOF-Trajectory-Simulation/trajectory/main.py in __init__(self, initial_long, initial_lat, variable, default, data_loc, run_date, forcast_time, forcast_plus_time, fast)
#     200             self.forcast_time=forcast_time
#     201             self.run_time=forcast_plus_time
# --> 202             self.df,self.points=self.load_data(closest(self.centre_lat,.25),closest(self.centre_long,.25))
#     203
#     204             if self.fast == True:
#
# ~/Documents/Projects/6DOF-Trajectory-Simulation/trajectory/main.py in load_data(self, lats, longs)
#     276                         f.write(chunk)
#     277         if os.path.getsize("%s/%s_%s_%s_%s_%s.grb2"%(self.data_loc,lat_bottom,long_left,self.date,self.forcast_time,self.run_time))<1000:
# --> 278             raise RuntimeError("The weather data you requested was not found, this is usually because it was for an invalid date/time. lat=%s,long=%s was requested"%(lat,longi))
#     279         data=iris.load("%s/%s_%s_%s_%s_%s.grb2"%(self.data_loc,lat_bottom,long_left,self.date,self.forcast_time,self.run_time))
#     280         for index,row in enumerate(data):
#
# UnboundLocalError: local variable 'lat' referenced before assignment

# %%
import sys
sys.path.append("/Users/jago/Downloads")
import netCDF4 as nc

# %%
ds = nc.Dataset("data/wind/radar/radar-mst_capel-dewi_20201210_st300_cartesian_v3.nc")

# %%
len(ds["eastward_wind"][:])
# Out:
# 275
