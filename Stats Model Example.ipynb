# %%
# %matplotlib notebook
import campyros.statistical as stats 
import campyros.plot as plt
import matplotlib.pyplot as pyplot
#pyplot.rcParams["figure.figsize"] = (15,10)#Comment this out if using matplotlib notebook

# %% [markdown]
# ## Run the stats model
# This will take a long time, if you're just testing reduce the number of runs to around 100 in the json file.
# Approximatly 5000 runs are required for the results to be normally distributed for a full model.

# %%
model = stats.StatisticalModel("stats_settings.json")
model.run_model()

# %% [markdown]
# ## Loads results and calculate stats

# %%
save_loc = "results/stats_example/stats_example"
max_itts = 2500

l_mu,l_cov,ap_mu,ap_cov,ap_dat,l_dat,x,y,z,t=stats.analyse(save_loc,max_itts)

# %% [markdown]
# Plot of landing sites

# %%
plt.stats_landing(l_mu,l_cov,data=l_dat)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Plot of apogees

# %%
plt.stats_apogee(ap_mu,ap_cov,apogee=ap_dat,
                 landing_mu=l_mu,landing_cov=l_cov,landing=l_dat)
# Out:
# <img src="data:image/png;base64,..." width="957">
# /home/jago/Documents/Projects/CamPyRoS/campyros/plot.py:847: MatplotlibDeprecationWarning:Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().

# %% [markdown]
# Plot of trajectories

# %%
plt.stats_trajectories(x,y,z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Plot of trajectories with landing and apogee covariant elipses

# %%
plt.stats_trajectories(x,y,z,
                       apogee_mu=ap_mu,apogee_cov=ap_cov,
                       landing_mu=l_mu,landing_cov=l_cov)
# Out:
# <img src="data:image/png;base64,..." width="935">

# %% [markdown]
# Plot of altitude time with standard errors
# Warning, the following graph takes a long time to run

# %%
plt.stats_alt(z,t,show_means=True)
# Out:
# <img src="data:image/png;base64,..." width="960">

# %% [markdown]
# I think the means/error bounds are wiggly because the timesteps get long on the way down.

# %%
help(plt)
# Out:
# Help on module campyros.plot in campyros:
#
# NAME
#     campyros.plot - 6DOF Trajectory Simulator
#
# DESCRIPTION
#     Various useful plots of the outputted data
#
# FUNCTIONS
#     animate_orientation(simulation_output, frames=500)
#         Shows an animation of the orientation against time, alongside an animation of altitude against time for reference
#
#         Parameters
#         ----------
#         simulation_output: pandas array
#             Simulation output from a Rocket.run() method. Should contain the following data:
#
#     elipse(u, v, a, b, c)
#
#     fix_ypr(point)
#
#     get_velocity_magnitude(df)
#
#     inertial_position(simulation_output)
#
#     plot_aero(simulation_output, rocket)
#         Plots the following:
#         - Aerodynamic forces against time
#         - COG and COP against time
#         - Angles of attack against time
#
#         Parameters
#         ----------
#         simulation_output: pandas array
# ...
