# %%
#%matplotlib notebook
import trajectory.statistical as stats 
import trajectory.plot as plt
import matplotlib.pyplot as pyplot
pyplot.rcParams["figure.figsize"] = (15,10)

# %% [markdown]
# I find it useful to analyse the results of the stats models in a jupyter notebook because then if something goes wrong you don't have to reload the entire data set (i.e. you can re run othercells while leaving the one below untouched).

# %%
save_loc = "results/stats_example"
max_itts = 105

l_mu,l_cov,ap_mu,ap_cov,ap_dat,l_dat,x,y,z,t=stats.analyse(save_loc,max_itts)

# %%
plt.stats_landing(l_mu,l_cov,data=l_dat)

# %%
plt.stats_apogee(ap_mu,ap_cov,apogee=ap_dat,landing_mu=l_mu,landing_cov=l_cov,landing=l_dat)

# %%
plt.stats_trajectories(x,y,z)

# %%
plt.stats_trajectories(x,y,z,apogee_mu=ap_mu,apogee_cov=ap_cov,landing_mu=l_mu,landing_cov=l_cov)

# %% [markdown]
# Warning, the following graph takes a long time to run

# %%
plt.stats_alt(z,t,show_means=True)

# %% [markdown]
# I think the means/error bounds are wiggly because the timesteps get really long on the way down.
