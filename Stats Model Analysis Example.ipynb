# %%
#%matplotlib notebook
import trajectory.statistical as stats 
import trajectory.plot as plt
import matplotlib.pyplot as pyplot
pyplot.rcParams["figure.figsize"] = (15,10)

# %%
save_loc = "results/stats_example_massive_launch"
max_itts = 16

l_mu,l_cov,ap_mu,ap_cov,ap_dat,l_dat,x,y,z,t=stats.analyse(save_loc,max_itts)

# %%
plt.stats_landing(l_mu,l_cov,data=l_dat,apogee=ap_dat)

# %%
pyplot.rcParams["figure.figsize"] = (15,15)
plt.stats_apogee(ap_mu,ap_cov,apogee=ap_dat,
                 landing_mu=l_mu,landing_cov=l_cov,landing=l_dat)

# %%
plt.stats_trajectories(x,y,z)

# %%
plt.stats_trajectories(x,y,z,
                       apogee_mu=ap_mu,apogee_cov=ap_cov,
                       landing_mu=l_mu,landing_cov=l_cov)

# %% [markdown]
# Warning, the following graph takes a long time to run

# %%
pyplot.rcParams["figure.figsize"] = (15,10)
plt.stats_alt(z,t,show_means=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-3d2d5c82a7c6> in <module>
#       1 pyplot.rcParams["figure.figsize"] = (15,10)
# ----> 2 plt.stats_alt(z,t,show_means=True)
#
# ~/Documents/Projects/6DOF-Trajectory-Simulation/trajectory/plot.py in stats_alt(z, t, show_means, sigma)
#     717             t_alts=[]
#     718             for (itt,data) in z.iteritems():
# --> 719                 alt=data[(t[itt]-time).abs().argsort()[:1]].astype(float).to_numpy()[0]
#     720                 t_alts.append(alt)
#     721             mean_alts.append(np.mean(t_alts))
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1111             key = check_bool_indexer(self.index, key)
#    1112
# -> 1113         return self._get_with(key)
#    1114
#    1115     def _get_with(self, key):
#
# ...

# %% [markdown]
# I think the means/error bounds are wiggly because the timesteps get long on the way down.
